# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri22j/DATA_SCIENCE_LAB_SE_B_26/blob/main/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if not isinstance(n, int):
        return "Input must be an integer"
    elif n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

n = int(input("Enter a number: "))
result = factorial(n)

print("Factorial of", n, "is:", result)
# Out:
# Enter a number: 5
# Factorial of 5 is: 120

# %%
# Function to check palindrome
def is_palindrome(number):
    num_str = str(number)
    reversed_num_str = num_str[::-1]

    if num_str == reversed_num_str:
        return True
    else:
        return False


# Taking input from user
num_input = int(input("Enter a number: "))

# Checking palindrome
if is_palindrome(num_input):
    print(f"{num_input} is a palindrome.")
else:
    print(f"{num_input} is not a palindrome.")
# Out:
# Enter a number: 6
# 6 is a palindrome.
