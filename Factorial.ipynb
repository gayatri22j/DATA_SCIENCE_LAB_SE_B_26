# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri22j/DATA_SCIENCE_LAB_SE_B_26/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if not isinstance(n, int):
        return "Input must be an integer"
    elif n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

# Call the function and print the result
print(factorial(5))
# Out:
# 120

# %%
def factorial(n):
    if not isinstance(n, int):
        return "Input must be an integer"
    elif n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact

n = int(input("Enter a number: "))
result = factorial(n)

print("Factorial of", n, "is:", result)
# Out:
# Enter a number: 7
# Factorial of 7 is: 5040

# %%
def is_palindrome(number):
    num_str = str(number)
 reversed = num_str[::-1]

    if num_str == reversed_num_str:
        return True
    else:
        return False

    num_input = int(input("Enter a number: "))
    if is_palindrome(num_input):
        print(f"{num_input} is a palindrome.")
    else:
        print(f"{num_input} is not a palindrome.")
# Out:
#   File "<tokenize>", line 3
#     reversed = num_str[::-1]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
num = int(input("Enter a number to display its multiplication table: "))
print(f"Multiplication table for {num}:")
for i in range(1, 11):
   print(f"{num} * {i} = {num * i}")

# %%
def is_palindrome(number):
    num_str = str(number)
 reversed = num_str[::-1]

    if num_str == reversed_num_str:
        return True
    else:
        return False

    num_input = int(input("Enter a number: "))
    if is_palindrome(num_input):
        print(f"{num_input} is a palindrome.")
    else:
        print(f"{num_input} is not a palindrome.")
