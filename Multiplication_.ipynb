# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri22j/DATA_SCIENCE_LAB_SE_B_26/blob/main/Multiplication_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number to display its multiplication table: "))
print(f"Multiplication table for {num}:")
for i in range(1, 11):
   print(f"{num} * {i} = {num * i}")
# Out:
# Enter a number to display its multiplication table: 5
# Multiplication table for 5:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
